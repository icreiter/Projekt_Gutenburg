# %%
driver = webdriver.Chrome()

# open project Gutenberg website for Chinese books
driver.get("https://www.gutenberg.org/browse/languages/zh")

# %%
# erste Probe 

url = 'https://www.gutenberg.org/browse/languages/zh'
# open project Gutenberg website for Chinese books
# 走訪頁面
def visit():
    driver.get(url)

# get the book#ID
def getBookID():
    driver.find_elements(
        By.CSS_SELECTOR,
        "div.pgdbbylanguage li.pgdbetext[href^=\/results]"
    )
#

# regular expression to get text only Chinese text
#getZH = r'[\u4E00-\u9FFF]'

# %%
# erste Probe lauft

visit()

# %%
# kurze notizen

div class = "pgdbbylanguage"

li class = "pgdbetext"

# %%
# erste Version

url = 'https://www.gutenberg.org/browse/languages/zh'

res = req.get(url)

soup = bs(res.text, 'lxml')

ebook_links = soup.select(
    'a[href^="/ebooks/"]'
)

ebook_ids = [link['href'].split('/')[2] for link in ebook_links]

print(ebook_ids)
# Out:
# ['', '', 'bookshelf', 'offline_catalogs.html', '25328', '24225', '24185', '27119', '38585', '12479', '25146', '25288', '23825', '25393', '25501', '23938', '54494', '24068', '27686', '25196', '24048', '27330', '23873', '27399', '38585', '27059', '27060', '26904', '26886', '25352', '24051', '25422', '23841', '26921', '24230', '27332', '27331', '23585', '24264', '24041', '43014', '25217', '52269', '26932', '25246', '26739', '26873', '25606', '23835', '23839', '62791', '27023', '25360', '24106', '7215', '24027', '27329', '25385', '23915', '27581', '24143', '23982', '27582', '57227', '25349', '24141', '24239', '27207', '27016', '27023', '25362', '7271', '7260', '7272', '7273', '7270', '25246', '25696', '25368', '52278', '52280', '7216', '52276', '24004', '7367', '7483', '7484', '25168', '7209', '24058', '52271', '25262', '26872', '24049', '26931', '23909', '7290', '7285', '7286', '7287', '7288', '7289', '52323', '52270', '24050', '24040', '26904', '25236', '23914', '23948', '24098', '54777', '7218', '23855', '26920', '27753', '23844', '27218', '23814', '25369', '23817', '27108', '25374', '24223', '25287', '24234', '24098', '25202', '49965', '24039', '7337', '49965', '4094', '3100', '4094', '3100', '25557', '24060', '24169', '24138', '54756', '24139', '25379', '54494', '24038', '7341', '25123', '25417', '23822', '24162', '26729', '57248', '27415', '49965', '38585', '38580', '49965', '38585', '38580', '54777', '54433', '54433', '25367', '23818', '25377', '25247', '26904', '26886', '24059', '26904', '23850', '25124', '56291', '27087', '26979', '25298', '7217', '27596', '25280', '25414', '24228', '23945', '7332', '7330', '7327', '7331', '7328', '7329', '23822', '23951', '24229', '24047', '52278', '25228', '23867', '27216', '23908', '25250', '23907', '52205', '25380', '25471', '23823', '26904', '27172', '25558', '23950', '57227', '25248', '27145', '4580', '4572', '4573', '4574', '4575', '4576', '4577', '4578', '4579', '26871', '23824', '23822', '24170', '54784', '7340', '25561', '24154', '23910', '25559', '25346', '27166', '24042', '25271', '25423', '25297', '25242', '25332', '23854', '27122', '23949', '7406', '25249', '23981', '24144', '54820', '54820', '52199', '24178', '24137', '57238', '27414', '30465', '24240', '24273', '54820', '54820', '27184', '25259', '25194', '26922', '27059', '25218', '25431', '25606', '23947', '25134', '51828', '26161', '27088', '24233', '27107', '56202', '25226', '62791', '24193', '25498', '38580', '38580', '27148', '23833', '7383', '25223', '25366', '25192', '52238', '27292', '7312', '7317', '7313', '7314', '7315', '7316', '25375', '23844', '26737', '23863', '26876', '25376', '24226', '25167', '25716', '25716', '23913', '25273', '27104', '25279', '25253', '23983', '25173', '12407', '23864', '24038', '24114', '24028', '27123', '25321', '7349', '23849', '26970', '2090', '30544', '7266', '7468', '2090', '24142', '23878', '24422', '24224', '23877', '27105', '25636', '26738', '25399', '24079', '25250', '25137', '24183', '12408', '26904', '52275', '24232', '26876', '52280', '25329', '26886', '51620', '24111', '27858', '20968', '54784', '7221', '26888', '25397', '25161', '24112', '54784', '29032', '56202', '24029', '7220', '23906', '27026', '26746', '25214', '25162', '27291', '25314', '27108', '25328', '25517', '25142', '67976', '25160', '25121', '25421', '27291', '30465', '7219', '25187', '25219', '23843', '25327', '24052', '23962', '25225', '23834', '25225', '25243', '27328', '54567', '24113', '25402', '24099', '54567', '23865', '24227', '27768', '23827', '25347', '25252', '24156', '24032', '23838', '52280', '29079', '25237', '25229', '25195', '56202', '43009', '52200', '27204', '27185', '25286', '23854', '25251', '24733', '28714', '23838', '23842', '27082', '25130', '25348', '23876', '25324', '7408', '24169', '24060', '25321', '25521', '24231', '27171', '26738', '27294', '23841', '25649', '26748', '25289', '24037', '7458', '25365', '7454', '7455', '7456', '7457', '43010', '25260', '25602', '27017', '25169', '2 ...

# %%
# import regex package
import re

# from selenium.webdriver.chrome.service import Service
from selenium import webdriver

import requests as req

# import BeartifulSoup
from bs4 import BeautifulSoup as bs

# take a nap
from time import sleep

# to handle the exception for timeout
from selenium.common.exceptions import TimeoutException

# tool for dynamic website, to wait for certain element, usually using with expected_conditions
from selenium.webdriver.support.ui import WebDriverWait

# using with WebDriverWait ，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

# 整理 json 使用的工具
import json

# 執行 command 的時候用的
import os

# 子處理程序，用來取代 os.system 的功能
import subprocess

# 下載檔案的工具
import wget


# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
my_options.add_argument("--lang=zh-TW")  #設定為正體中文

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options
)

# 建立儲存圖片、影片的資料夾
folderPath = 'project_gutenberg'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# 放置爬取的資料
listData = []

# %%
# 執行 command 的時候用的
import os

# import regex package
import re

import requests as req

# import BeartifulSoup
from bs4 import BeautifulSoup as bs


# 建立儲存路徑
folderPath = 'project_gutenberg'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# 放置爬取的資料
listData = []

# %%
# get bookID

url = 'https://www.gutenberg.org/browse/languages/zh'

res = req.get(url)

soup = bs(res.text, 'lxml')

ebook_links = soup.select(
    'div.pgdbbylanguage a[href^="/ebooks/"]'
)

ebook_ids = [link['href'].split('/')[2] for link in ebook_links]

print(ebook_ids)
# Out:
# ['25328', '24225', '24185', '27119', '38585', '12479', '25146', '25288', '23825', '25393', '25501', '23938', '54494', '24068', '27686', '25196', '24048', '27330', '23873', '27399', '38585', '27059', '27060', '26904', '26886', '25352', '24051', '25422', '23841', '26921', '24230', '27332', '27331', '23585', '24264', '24041', '43014', '25217', '52269', '26932', '25246', '26739', '26873', '25606', '23835', '23839', '62791', '27023', '25360', '24106', '7215', '24027', '27329', '25385', '23915', '27581', '24143', '23982', '27582', '57227', '25349', '24141', '24239', '27207', '27016', '27023', '25362', '7271', '7260', '7272', '7273', '7270', '25246', '25696', '25368', '52278', '52280', '7216', '52276', '24004', '7367', '7483', '7484', '25168', '7209', '24058', '52271', '25262', '26872', '24049', '26931', '23909', '7290', '7285', '7286', '7287', '7288', '7289', '52323', '52270', '24050', '24040', '26904', '25236', '23914', '23948', '24098', '54777', '7218', '23855', '26920', '27753', '23844', '27218', '23814', '25369', '23817', '27108', '25374', '24223', '25287', '24234', '24098', '25202', '49965', '24039', '7337', '49965', '4094', '3100', '4094', '3100', '25557', '24060', '24169', '24138', '54756', '24139', '25379', '54494', '24038', '7341', '25123', '25417', '23822', '24162', '26729', '57248', '27415', '49965', '38585', '38580', '49965', '38585', '38580', '54777', '54433', '54433', '25367', '23818', '25377', '25247', '26904', '26886', '24059', '26904', '23850', '25124', '56291', '27087', '26979', '25298', '7217', '27596', '25280', '25414', '24228', '23945', '7332', '7330', '7327', '7331', '7328', '7329', '23822', '23951', '24229', '24047', '52278', '25228', '23867', '27216', '23908', '25250', '23907', '52205', '25380', '25471', '23823', '26904', '27172', '25558', '23950', '57227', '25248', '27145', '4580', '4572', '4573', '4574', '4575', '4576', '4577', '4578', '4579', '26871', '23824', '23822', '24170', '54784', '7340', '25561', '24154', '23910', '25559', '25346', '27166', '24042', '25271', '25423', '25297', '25242', '25332', '23854', '27122', '23949', '7406', '25249', '23981', '24144', '54820', '54820', '52199', '24178', '24137', '57238', '27414', '30465', '24240', '24273', '54820', '54820', '27184', '25259', '25194', '26922', '27059', '25218', '25431', '25606', '23947', '25134', '51828', '26161', '27088', '24233', '27107', '56202', '25226', '62791', '24193', '25498', '38580', '38580', '27148', '23833', '7383', '25223', '25366', '25192', '52238', '27292', '7312', '7317', '7313', '7314', '7315', '7316', '25375', '23844', '26737', '23863', '26876', '25376', '24226', '25167', '25716', '25716', '23913', '25273', '27104', '25279', '25253', '23983', '25173', '12407', '23864', '24038', '24114', '24028', '27123', '25321', '7349', '23849', '26970', '2090', '30544', '7266', '7468', '2090', '24142', '23878', '24422', '24224', '23877', '27105', '25636', '26738', '25399', '24079', '25250', '25137', '24183', '12408', '26904', '52275', '24232', '26876', '52280', '25329', '26886', '51620', '24111', '27858', '20968', '54784', '7221', '26888', '25397', '25161', '24112', '54784', '29032', '56202', '24029', '7220', '23906', '27026', '26746', '25214', '25162', '27291', '25314', '27108', '25328', '25517', '25142', '67976', '25160', '25121', '25421', '27291', '30465', '7219', '25187', '25219', '23843', '25327', '24052', '23962', '25225', '23834', '25225', '25243', '27328', '54567', '24113', '25402', '24099', '54567', '23865', '24227', '27768', '23827', '25347', '25252', '24156', '24032', '23838', '52280', '29079', '25237', '25229', '25195', '56202', '43009', '52200', '27204', '27185', '25286', '23854', '25251', '24733', '28714', '23838', '23842', '27082', '25130', '25348', '23876', '25324', '7408', '24169', '24060', '25321', '25521', '24231', '27171', '26738', '27294', '23841', '25649', '26748', '25289', '24037', '7458', '25365', '7454', '7455', '7456', '7457', '43010', '25260', '25602', '27017', '25169', '25147', '27302', '27734', '26877', '25245', '25 ...

# %%
for id in ebook_ids:
    url = f'https://www.gutenberg.org/cache/epub/{id}/pg{id}.txt'

    res = req.get(url)

    if res.status_code == 200:
        content = res.text

        contCh = re.sub(r'[^\u4e00-\u9fa5\u3000-\u303F\uff00-\uffef]', '', content)

    file_path = os.path.join(folderPath, f'ebook_{id}.txt')
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(contCh)
    
    print(f'已存{id}.txt')
# Out:
# 已存25328.txt
# 已存24225.txt
# 已存24185.txt
# 已存27119.txt
# 已存38585.txt
# 已存12479.txt
# 已存25146.txt
# 已存25288.txt
# 已存23825.txt
# 已存25393.txt
# 已存25501.txt
# 已存23938.txt
# 已存54494.txt
# 已存24068.txt
# 已存27686.txt
# 已存25196.txt
# 已存24048.txt
# 已存27330.txt
# 已存23873.txt
# 已存27399.txt
# 已存38585.txt
# 已存27059.txt
# 已存27060.txt
# 已存26904.txt
# 已存26886.txt
# 已存25352.txt
# 已存24051.txt
# 已存25422.txt
# 已存23841.txt
# 已存26921.txt
# 已存24230.txt
# 已存27332.txt
# 已存27331.txt
# 已存23585.txt
# 已存24264.txt
# 已存24041.txt
# 已存43014.txt
# 已存25217.txt
# 已存52269.txt
# 已存26932.txt
# 已存25246.txt
# 已存26739.txt
# 已存26873.txt
# 已存25606.txt
# 已存23835.txt
# 已存23839.txt
# 已存62791.txt
# 已存27023.txt
# 已存25360.txt
# 已存24106.txt
# 已存7215.txt
# 已存24027.txt
# 已存27329.txt
# 已存25385.txt
# 已存23915.txt
# 已存27581.txt
# 已存24143.txt
# 已存23982.txt
# 已存27582.txt
# 已存57227.txt
# 已存25349.txt
# 已存24141.txt
# 已存24239.txt
# 已存27207.txt
# 已存27016.txt
# 已存27023.txt
# 已存25362.txt
# 已存7271.txt
# 已存7260.txt
# 已存7272.txt
# 已存7273.txt
# 已存7270.txt
# 已存25246.txt
# 已存25696.txt
# 已存25368.txt
# 已存52278.txt
# 已存52280.txt
# 已存7216.txt
# 已存52276.txt
# 已存24004.txt
# 已存7367.txt
# 已存7483.txt
# 已存7484.txt
# 已存25168.txt
# 已存7209.txt
# 已存24058.txt
# 已存52271.txt
# 已存25262.txt
# 已存26872.txt
# 已存24049.txt
# 已存26931.txt
# 已存23909.txt
# 已存7290.txt
# 已存7285.txt
# 已存7286.txt
# 已存7287.txt
# 已存7288.txt
# 已存7289.txt
# 已存52323.txt
# 已存52270.txt
# 已存24050.txt
# 已存24040.txt
# 已存26904.txt
# 已存25236.txt
# 已存23914.txt
# 已存23948.txt
# 已存24098.txt
# 已存54777.txt
# 已存7218.txt
# 已存23855.txt
# 已存26920.txt
# 已存27753.txt
# 已存23844.txt
# 已存27218.txt
# 已存23814.txt
# 已存25369.txt
# 已存23817.txt
# 已存27108.txt
# 已存25374.txt
# 已存24223.txt
# 已存25287.txt
# 已存24234.txt
# 已存24098.txt
# 已存25202.txt
# 已存49965.txt
# 已存24039.txt
# 已存7337.txt
# 已存49965.txt
# 已存4094.txt
# 已存3100.txt
# 已存4094.txt
# 已存3100.txt
# 已存25557.txt
# 已存24060.txt
# 已存24169.txt
# 已存24138.txt
# 已存54756.txt
# 已存24139.txt
# 已存25379.txt
# 已存54494.txt
# 已存24038.txt
# 已存7341.txt
# 已存25123.txt
# 已存25417.txt
# 已存23822.txt
# 已存24162.txt
# 已存26729.txt
# 已存57248.txt
# 已存27415.txt
# 已存49965.txt
# 已存38585.txt
# 已存38580.txt
# 已存49965.txt
# 已存38585.txt
# 已存38580.txt
# 已存54777.txt
# 已存54433.txt
# 已存54433.txt
# 已存25367.txt
# 已存23818.txt
# 已存25377.txt
# 已存25247.txt
# 已存26904.txt
# 已存26886.txt
# 已存24059.txt
# 已存26904.txt
# 已存23850.txt
# 已存25124.txt
# 已存56291.txt
# 已存27087.txt
# 已存26979.txt
# 已存25298.txt
# 已存7217.txt
# 已存27596.txt
# 已存25280.txt
# 已存25414.txt
# 已存24228.txt
# 已存23945.txt
# 已存7332.txt
# 已存7330.txt
# 已存7327.txt
# 已存7331.txt
# 已存7328.txt
# 已存7329.txt
# 已存23822.txt
# 已存23951.txt
# 已存24229.txt
# 已存24047.txt
# 已存52278.txt
# 已存25228.txt
# 已存23867.txt
# 已存27216.txt
# 已存23908.txt
# 已存25250.txt
# 已存23907.txt
# 已存52205.txt
# 已存25380.txt
# 已存25471.txt
# 已存23823.txt
# 已存26904.txt
# 已存27172.txt
# 已存25558.txt
# 已存23950.txt
# 已存57227.txt
# 已存25248.txt
# 已存27145.txt
# 已存4580.txt
# 已存4572.txt
# 已存4573.txt
# 已存4574.txt
# 已存4575.txt
# 已存4576.txt
# 已存4577.txt
# 已存4578.txt
# 已存4579.txt
# 已存26871.txt
# 已存23824.txt
# 已存23822.txt
# 已存24170.txt
# 已存54784.txt
# 已存7340.txt
# 已存25561.txt
# 已存24154.txt
# 已存23910.txt
# 已存25559.txt
# 已存25346.txt
# 已存27166.txt
# 已存24042.txt
# 已存25271.txt
# 已存25423.txt
# 已存25297.txt
# 已存25242.txt
# 已存25332.txt
# 已存23854.txt
# 已存27122.txt
# 已存23949.txt
# 已存7406.txt
# 已存25249.txt
# 已存23981.txt
# 已存24144.txt
# 已存54820.txt
# 已存54820.txt
# 已存52199.txt
# 已存24178.txt
# 已存24137.txt
# 已存57238.txt
# 已存27414.txt
# 已存30465.txt
# 已存24240.txt
# 已存24273.txt
# 已存54820.txt
# 已存54820.txt
# 已存27184.txt
# 已存25259.txt
# 已存25194.txt
# 已存26922.txt
# 已存27059.txt
# 已存25218.txt
# 已存25431.txt
# 已存25606.txt
# 已存23947.txt
# 已存25134.txt
# 已存51828.txt
# 已存26161.txt
# 已存27088.txt
# 已存24233.txt
# 已存27107.txt
# 已存56202.txt
# 已存25226.txt
# 已存62791.txt
# 已存24193.txt
# 已存25498.txt
# 已存38580.txt
# 已存38580.txt
# 已存27148.txt
# 已存23833.txt
# 已存7383.txt

# %%
# 16.12.2024 Probe
# 執行 command 的時候用的
import os

# import regex package
import re

import requests as req

# import BeartifulSoup
from bs4 import BeautifulSoup as bs


# 建立儲存路徑
folderPath = 'project_gutenberg'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# 放置爬取的資料
listData = []

# %%
# get bookID

url = 'https://www.gutenberg.org/browse/languages/zh'

res = req.get(url)

soup = bs(res.text, 'lxml')

ebook_links = soup.select(
    'div.pgdbbylanguage li.pgdbetext a[href^="/ebooks/"]'
)

for link in ebook_links:
    parent_text = link.parent.get_text()
    a_text = link.get_text()

    if "(Chinese)" in parent_text and re.search(r'[\u4e00-\u9fa5]', a_text):
        id = link['href'].split('/')[2]
        title = ''.join(re.findall(r'[\u4e00-\u9fa5]', a_text))

        listData.append((id, title))

#ebook_ids = [link['href'].split('/')[2] for link in ebook_links]

for id, title in listData:
    print(f"({id}, {title}),")
# Out:
# (25328, 豆棚閒話),
# (24225, 戲中戲),
# (24185, 比目魚),
# (27119, 比目魚),
# (12479, 三字經),
# (25146, 山水情),
# (25288, 山海經),
# (23825, 施公案),
# (25393, 施公案),
# (25501, 易經),
# (23938, 木蘭奇女傳),
# (54494, 海公案),
# (24068, 燕丹子),
# (27686, 狄公案),
# (25196, 百家姓),
# (24048, 禮記),
# (27330, 綠牡丹),
# (23873, 詩經),
# (27399, 麟兒報),
# (26904, 天豹圖),
# (26886, 梁公九諫),
# (25352, 長恨歌),
# (24051, 李娃傳),
# (25422, 玉樓春),
# (23841, 漢書),
# (26921, 引鳳蕭),
# (24230, 今古奇觀),
# (27332, 後西游記),
# (27331, 飛跎全傳),
# (23585, 佛說四十二章經),
# (24264, 紅樓夢),
# (24041, 洛神賦),
# (43014, 晁氏儒言一卷),
# (25217, 水滸後傳),
# (52269, 幼學瓊林),
# (26932, 治世餘聞),
# (25246, 琵琶記),
# (26739, 雪月梅傳),
# (26873, 龍川詞),
# (25606, 三國志),
# (23835, 隋唐演義),
# (23839, 論語),
# (62791, 滬語開路),
# (27023, 白圭志),
# (25360, 孟子字義疏證),
# (24106, 安樂集),
# (7215, 鄧析子),
# (24027, 醉醒石),
# (27329, 唐鍾馗平鬼傳),
# (25385, 春秋繁露),
# (23915, 虬髯客傳),
# (27581, 吳船錄),
# (24143, 星槎勝覽),
# (23982, 星槎勝覽),
# (27582, 喻世明言),
# (57227, 平妖傳),
# (25349, 東周列國志),
# (24141, 警世通言),
# (24239, 醒世恆言),
# (27207, 封氏聞見記),
# (27023, 白圭志),
# (25362, 搜神記),
# (7271, 搜神記),
# (7260, 搜神記),
# (7272, 搜神記),
# (7273, 搜神記),
# (7270, 搜神記),
# (25246, 琵琶記),
# (25696, 抱朴子),
# (25368, 西京雜記),
# (52278, 幽明錄),
# (52280, 明鏡公案),
# (7216, 公孫龍子),
# (52276, 竇娥冤),
# (24004, 竇娥寃),
# (7367, 管子),
# (7483, 管子),
# (7484, 管子),
# (25168, 鬼谷子),
# (7209, 鬼谷子),
# (24058, 穆天子传),
# (52271, 漢武帝別國洞冥記),
# (25262, 日知錄),
# (26872, 海上花列傳),
# (24049, 韩非子),
# (26931, 風月夢),
# (23909, 韓詩外傳),
# (7290, 韓詩外傳),
# (7285, 韓詩外傳),
# (7286, 韓詩外傳),
# (7287, 韓詩外傳),
# (7288, 韓詩外傳),
# (7289, 韓詩外傳),
# (52323, 唐诗三百首),
# (52270, 長生殿),
# (24050, 菜根譚),
# (24040, 菜根譚前後集),
# (26904, 天豹圖),
# (25236, 筠州黃檗山斷際禪師傳法心要),
# (23914, 山水小牘),
# (23948, 高士傳),
# (24098, 金剛般若波羅蜜經),
# (54777, 天妃顯聖錄),
# (7218, 三略),
# (23855, 明夷待訪錄),
# (26920, 鹽鐵論),
# (27753, 一枕奇),
# (23844, 六祖壇經),
# (27218, 臺灣外紀),
# (23814, 賈誼新書),
# (25369, 金石緣),
# (23817, 閱微草堂筆記),
# (27108, 醒夢駢言),
# (25374, 孔叢子),
# (24223, 小爾雅),
# (25287, 續世說),
# (24234, 桃花扇),
# (24098, 金剛般若波羅蜜經),
# (25202, 補紅樓夢),
# (24039, 老子),
# (7337, 道德經),
# (25557, 臺灣通史唐山過海的故事),
# (24060, 李太白集),
# (24169, 李太白集),
# (24138, 官場現形記),
# (54756, 官場現形記),
# (24139, 官場現形記),
# (25379, 文明小史),
# (54494, 海公案),
# (24038, 孫子算經),
# (7341, 列子),
# (25123, 脾胃論),
# (25417, 李賀詩選),
# (23822, 文心雕龍),
# (24162, 二刻拍案惊奇),
# (26729, 二刻拍案驚奇),
# (57248, 初刻拍案驚奇),
# (27415, 殺子報),
# (54777, 天妃顯聖錄),
# (54433, 西海紀遊草),
# (25367, 漱玉詞),
# (23818, 鏡花緣),
# (25377, 鏡花緣),
# (25247, 李義山詩集),
# (26904, 天豹圖),
# (26886, 梁公九諫),
# (24059, 淮南子),
# (26904, 天豹圖),
# (23850, 老殘遊記),
# (25124, 老殘遊記),
# (56291, 老殘遊記續集),
# (26979, 海島算經),
# (25298, 郁離子),
# (7217, 人物志),
# (27596, 隋唐嘉話),
# (25280, 大唐新語),
# (25414, 列仙傳),
# (24228, 列女傳),
# (23945, 新序),
# (7332, 說苑),
# (7330, 說苑),
# (7327, 說苑),
# (7331, 說苑),
# (7328, 說苑),
# (7329, 說苑),
# (23822, 文心雕龍),
# (23951, 西京雜記),
# (24229, 舊唐書),
# (24047, 世說新語),
# (52278, 幽明錄),
# (25228, 樂章集),
# (23867, 斬鬼傳),
# (27216, 斬鬼傳),
# (23908, 夢中緣),
# (25250, 合錦回文傳),
# (23907, 無聲戲),
# (52205, 肉蒲團),
# (25380, 閒情偶寄),
# (25471, 闲情偶寄),
# (23823, 弟子規),
# (26904, 天豹圖),
# (27172, 庚巳編),
# (25558, 呻吟語),
# (23950, 三國志演義),
# (57227, 平妖傳),
# (25248, 平妖傳),
# (27145, 殘唐五代史演義傳),
# (4580, 粉妝樓),
# (4572, 粉妝樓回),
# (4573, 粉妝樓回),
# (4574, 粉妝樓回),
# (4575, 粉妝樓回),
# (4576, 粉妝樓回),
# (4577, 粉妝樓回),
# (4578, 粉妝樓回),
# (4579, 粉妝樓回),
# (26871, 粉妝樓全傳),
# (23824, 說唐),
# (23822, 文心雕龍),
# (24170, 常言道),
# (54784, 大唐三藏取經詩話),
# (7340, 六韜),
# (25561, 癡人說夢記),
# (24154, 癡人說夢記),
# (23910, 封神演義),
# (25559, 中國小說史略),
# (25346, 南腔北調集),
# (27166, 吶喊),
# (24042, 徬徨),
# (25271, 朝花夕拾),
# (25423, 狂人日記),
# (25297, 狂人日記),
# (25242, 野草),
# (25332, 阿正傳),
# (23854, 文子),
# (27122, 老學庵筆記),
# (23949, 茶經),
# (7406, 茶經),
# (25249, 近思錄),
# (23981, 瀛涯勝覽),
# (24144, 瀛涯勝覽),
# (52199, 漢宮秋),
# (24178, 孟子),
# (24137, 東京夢華錄),
# (57238, 白兔記),
# (27414, 好逑傳),
# (30465, 御製廣寒殿記),
# (24240, 墨子),
# (24273, 西湖佳話),
# (27184, 癡人福),
# (25259, 公墓),
# (25194, 飲水詞集),
# (26922, 春柳鶯),
# (25218, 六一詞),
# (25431, 歸田錄),
# (25606, 三國志),
# (23947, 蜀碧),
# (25134, 九尾狐),
# (51828, 聊齋志異),
# (26161, 醒世姻緣),
# (27088, 南部新書),
# (24233, 東度記),
# (27107, 金雲翹傳),
# (56202, 拾遺記),
# (25226, 負曝閒談),
# (62791, 滬語開路),
# (24193, 燕子箋),
# (25498, 佛說無量壽經),
# (27148, 蕉葉帕),
# (23833, 商君書),
# (7383, 商子),
# (25223, 俗話傾談),
# (25366, 慎子),
# (25192, 浮生六記),
# (52238, 枕中記),
# (27292, 夢溪筆談),
# (7312, 夢溪筆談),
# (7317, 夢溪筆談),
# (7313, 夢溪筆談),
# (7314, 夢溪筆談),
# (7315, 夢溪筆談),
# (7316, 夢溪筆談),
# (25375, 諧鐸),
# (23844, 六祖壇經),
# (26737, 幽閨記),
# (23863, 水滸傳),
# (26876, 文子),
# (25376, 三俠五義),
# (24226, 史記),
# (25167, 司馬法),
# (25716, 灵历集光),
# (25716, 灵历集光),
# (23913, 莊子的故事),
# (25273, 天工開物),
# (27104, 歸蓮夢),
# (25279, 錦香亭),
# (25253, 杜陽雜編),
# (23983, 斷鴻零雁記),
# (25173, 北夢瑣言),
# (12407, 兵法),
# (23864, 孫子兵法),
# (24038, 孫子算經),
# (24114, 東坡志林),
# (24028, 東坡樂府),
# (27123, 水調歌頭),
# (25321, 蘇洵集),
# (7349, 孫子兵法道家新註解),
# (23849, 牡丹亭),
# (26970, 彭公案),
# (30544, 五孝傳),
# (7266, 搜神後記),
# (7468, 搜神後記),
# (24142, 轟天雷),
# (23878, 人間樂),
# (24422, 定情人),
# (24224, 平山冷燕),
# (23877, 玉嬌梨),
# (27105, 玉支机),
# (25636, 玉雙魚),
# (26738, 畫圖緣),
# (25399, 石點頭),
# (24079, 商界現形記),
# (25250, 合錦回文傳),
# (25137, 玉蟾記),
# (24183, 宋史),
# (12408, 周髀算經),
# (26904, 天豹圖),
# (52275, 孔雀東南飛),
# (24232, 孝經),
# (26876, 文子),
# (52280, 明鏡公案),
# (25329, 春秋配),
# (26886, 梁公九諫),
# (51620, 爾雅),
# (24111, 竹書紀年),
# (27858, 黄帝宅經),
# (54784, 大唐三藏取經詩話),
# (7221, 文淵閣四庫全書),
# (26888, 本草備要),
# (25397, 論衡),
# (25161, 魏鄭公諫錄),
# (24112, 人間詞話),
# (54784, 大唐三藏取經詩話),
# (29032, 海國春秋),
# (56202, 拾遺記),
# (24029, 冷眼观),
# (7220, 竹齋集),
# (23906, 西廂記),
# (27026, 豔異編),
# (26746, 分甘余話),
# (25214, 劍俠傳),
# (25162, 池北偶談),
# (27291, 文中子中說),
# (25314, 荀子集解),
# (27108, 醒夢駢言),
# (25328, 豆棚閒話),
# (25517, 傳習錄),
# (25142, 王陽明全集),
# (67976, 故事新讀本第一冊),
# (25160, 三字經),
# (25121, 花外集),
# (25421, 圍爐夜話),
# (27291, 文中子中說),
# (30465, 御製廣寒殿記),
# (7219, 尉繚子),
# (25187, 花月痕),
# (25219, 花月痕),
# (23843, 明月台),
# (25327, 兒女英雄傳),
# (24052, 玉壺淸話),
# (23962, 西遊記),
# (25225, 古文觀止),
# (23834, 青箱雜記),
# (25225, 古文觀止),
# (25243, 海遊記),
# (27328, 駐春園小史),
# (24113, 九命奇冤),
# (25402, 九命奇冤),
# (24099, 二十年目睹之怪現狀),
# (54567, 二十年目睹之怪現狀),
# (23865, 恨海),
# (24227, 情變),
# (27768, 瞎騙奇聞),
# (23827, 胡涂世界),
# (25347, 貞觀政要),
# (25252, 貞觀政要),
# (24156, 中國十大禁書之國色天香),
# (24032, 儒林外史),
# (23838, 楊家將),
# (52280, 明鏡公案),
# (29079, 五色石),
# (25237, 快士傳),
# (25229, 飛龍全傳),
# (25195, 風月鑒),
# (56202, 拾遺記),
# (43009, 古詩十九首),
# (52200, 金瓶梅),
# (27204, 滿江紅),
# (27185, 宛如約),
# (25286, 歡喜冤家),
# (23854, 文子),
# (25251, 八段錦),
# (24733, 辛棄疾詞選),
# (28714, 唐才子傳),
# (23838, 楊家將),
# (23842, 楊家將),
# (27082, 楊家將演義),
# (25130, 夜雨秋燈錄),
# (25348, 雙鳳奇緣),
# (23876, 徐霞客遊記),
# (25324, 玉台新詠),
# (7408, 申鑒),
# (24169, 李太白集),
# (24060, 李太白集),
# (25321, 蘇洵集),
# (25521, 玉梨魂),
# (24231, 韓湘子全傳),
# (27171, 鬼谷四友志),
# (26738, 畫圖緣),
# (27294, 方言),
# (23841, 漢書),
# (25649, 巧聯珠),
# (26748, 幻中游),
# (25289, 滄浪詩話),
# (24037, 顔氏家訓),
# (7458, 顔氏家訓),
# (25365, 顔氏家訓),
# (7454, 顔氏家訓),
# (7455, 顔氏家訓),
# (7456, 顔氏家訓),
# (7457, 顔氏家訓),
# (43010, 竹葉亭雜記),
# (25260, 豐收),
# (25602, 蘭花夢奇傳),
# (27017, 尹文子),
# (25169, 關尹子),
# (25147, 黃繡球),
# (27302, 鄰女語),
# (27734, 合浦珠),
# (26877, 珍珠舶),
# (25245, 子不語),
# (25315, 續子不語),
# (52206, 隨園詩話),
# (52267, 鶯鶯傳),
# (57278, 青樓夢),
# (27636, 沉沦),
# (27204, 滿江紅),
# (27459, 耳食錄),
# (26887, 桯史),
# (25543, 蜃樓志),
# (25284, 五鳳吟),
# (24294, 警悟鐘),
# (25350, 蕩寇志),
# (54670, 裨海紀遊),
# (25128, 孽海花),
# (25381, 幽夢影),
# (7420, 幽夢影),
# (7418, 幽夢影),
# (7419, 幽夢影),
# (27165, 西湖夢尋),
# (25401, 陶庵夢憶),
# (25414, 列仙傳),
# (24327, 何典),
# (7407, 棋經),
# (27092, 括異志),
# (24021, 杜騙新書),
# (27263, 張載集),
# (24272, 傷寒論),
# (26997, 朝野僉載),
# (24295, 遊仙窟),
# (25231, 遊仙窟),
# (24316, 花間集),
# (25131, 吳越春秋),
# (25391, 甌北詩話),
# (25125, 明皇雜錄),
# (25460, 詩品),
# (7342, 詩品),
# (25263, 周禮),
# (25392, 西湖二集),
# (23912, 千字文),
# (24075, 千字文),
# (24184, 千字文),
# (27398, 雞肋編),
# (30460, 出師表),
# (27217, 牛郎織女傳),
# (7376, 中庸章句),
# (7375, 大學章句),
# (25249, 近思錄),
# (23840, 近思錄),
# (23816, 朱子治家格言),
# (24110, 歐遊雜記),
# (25228, 樂章集),
# (25323, 狐狸緣全傳),
# (27403, 清代野记),
# (27402, 風流悟),
# (23911, 國語),
# (24136, 左傳),
# (25328, 豆棚閒話),
# (24225, 戲中戲),
# (24185, 比目魚),
# (27119, 比目魚),
# (12479, 三字經),
# (25146, 山水情),
# (25288, 山海經),
# (23825, 施公案),
# (25393, 施公案),
# (25501, 易經),
# (23938, 木蘭奇女傳),
# (54494, 海公案),
# (24068, 燕丹子),
# (27686, 狄公案),
# (25196, 百家姓),
# (24048, 禮記),
# (27330, 綠牡丹),
# (23873, 詩經),
# (27399, 麟兒報),
# (26904, 天豹圖),
# (26886, 梁公九諫),
# (25352, 長恨歌),
# (24051, 李娃傳),
# (25422, 玉樓春),
# (23841, 漢書),
# (26921, 引鳳蕭),
# (24230, 今古奇觀),
# (27332, 後西游記),
# (27331, 飛跎全傳),
# (23585, 佛說四十二章經),
# (24264, 紅樓夢),
# (24041, 洛神賦),
# (43014, 晁氏儒言一卷),
# (25217, 水滸後傳),
# (52269, 幼學瓊林),
# (26932, 治世餘聞),
# (25246, 琵琶記),
# (26739, 雪月梅傳),
# (26873, 龍川詞),
# (25606, 三國志),
# (23835, 隋唐演義),
# (23839, 論語),
# (62791, 滬語開路),
# (27023, 白圭志),
# (25360, 孟子字義疏證),
# (24106, 安樂集),
# (7215, 鄧析子),
# (24027, 醉醒石),
# (27329, 唐鍾馗平鬼傳),
# (25385, 春秋繁露),
# (23915, 虬髯客傳),
# (27581, 吳船錄),
# (24143, 星槎勝覽),
# (23982, 星槎勝覽),
# (27582, 喻世明言),
# (57227, 平妖傳),
# (25349, 東周列國志),
# (24141, 警世通言),
# (24239, 醒世恆言),
# (27207, 封氏聞見記),
# (27023, 白圭志),
# (25362, 搜神記),
# (7271, 搜神記),
# (7260, 搜神記),
# (7272, 搜神記),
# (7273, 搜神記),
# (7270, 搜神記),
# (25246, 琵琶記),
# (25696, 抱朴子),
# (25368, 西京雜記),
# (52278, 幽明錄),
# (52280, 明鏡公案),
# (7216, 公孫龍子),
# (52276, 竇娥冤),
# (24004, 竇娥寃),
# (7367, 管子),
# (7483, 管子),
# (7484, 管子),
# (25168, 鬼谷子),
# (7209, 鬼谷子),
# (24058, 穆天子传),
# (52271, 漢武帝別國洞冥記),
# (25262, 日知錄),
# (26872, 海上花列傳),
# (24049, 韩非子),
# (26931, 風月夢),
# (23909, 韓詩外傳),
# (7290, 韓詩外傳),
# (7285, 韓詩外傳),
# (7286, 韓詩外傳),
# (7287, 韓詩外傳),
# (7288, 韓詩外傳),
# (7289, 韓詩外傳),
# (52323, 唐诗三百首),
# (52270, 長生殿),
# (24050, 菜根譚),
# (24040, 菜根譚前後集),
# (26904, 天豹圖),
# (25236, 筠州黃檗山斷際禪師傳法心要),
# (23914, 山水小牘),
# (23948, 高士傳),
# (24098, 金剛般若波羅蜜經),
# (54777, 天妃顯聖錄),
# (7218, 三略),
# (23855, 明夷待訪錄),
# (26920, 鹽鐵論),
# (27753, 一枕奇),
# (23844, 六祖壇經),
# (27218, 臺灣外紀),
# (23814, 賈誼新書),
# (25369, 金石緣),
# (23817, 閱微草堂筆記),
# (27108, 醒夢駢言),
# (25374, 孔叢子),
# (24223, 小爾雅),
# (25287, 續世說),
# (24234, 桃花扇),
# (24098, 金剛般若波羅蜜經),
# (25202, 補紅樓夢),
# (24039, 老子),
# (7337, 道德經),
# (25557, 臺灣通史唐山過海的故事),
# (24060, 李太白集),
# (24169, 李太白集),
# (24138, 官場現形記),
# (54756, 官場現形記),
# (24139, 官場現形記),
# (25379, 文明小史),
# (54494, 海公案),
# (24038, 孫子算經),
# (7341, 列子),
# (25123, 脾胃論),
# (25417, 李賀詩選),
# (23822, 文心雕龍),
# (24162, 二刻拍案惊奇),
# (26729, 二刻拍案驚奇),
# (57248, 初刻拍案驚奇),
# (27415, 殺子報),
# (54777, 天妃顯聖錄),
# (54433, 西海紀遊草),
# (25367, 漱玉詞),
# (23818, 鏡花緣),
# (25377, 鏡花緣),
# (25247, 李義山詩集),
# (26904, 天豹圖),
# (26886, 梁公九諫),
# (24059, 淮南子),
# (26904, 天豹圖),
# (23850, 老殘遊記),
# (25124, 老殘遊記),
# (56291, 老殘遊記續集),
# (26979, 海島算經),
# (25298, 郁離子),
# (7217, 人物志),
# (27596, 隋唐嘉話),
# (25280, 大唐新語),
# (25414, 列仙傳),
# (24228, 列女傳),
# (23945, 新序),
# (7332, 說苑),
# (7330, 說苑),
# (7327, 說苑),
# (7331, 說苑),
# (7328, 說苑),
# (7329, 說苑),
# (23822, 文心雕龍),
# (23951, 西京雜記),
# (24229, 舊唐書),
# (24047, 世說新語),
# (52278, 幽明錄),
# (25228, 樂章集),
# (23867, 斬鬼傳),
# (27216, 斬鬼傳),
# (23908, 夢中緣),
# (25250, 合錦回文傳),
# (23907, 無聲戲),
# (52205, 肉蒲團),
# (25380, 閒情偶寄),
# (25471, 闲情偶寄),
# (23823, 弟子規),
# (26904, 天豹圖),
# (27172, 庚巳編),
# (25558, 呻吟語),
# (23950, 三國志演義),
# (57227, 平妖傳),
# (25248, 平妖傳),
# (27145, 殘唐五代史演義傳),
# (4580, 粉妝樓),
# (4572, 粉妝樓回),
# (4573, 粉妝樓回),
# (4574, 粉妝樓回),
# (4575, 粉妝樓回),
# (4576, 粉妝樓回),
# (4577, 粉妝樓回),
# (4578, 粉妝樓回),
# (4579, 粉妝樓回),
# (26871, 粉妝樓全傳),
# (23824, 說唐),
# (23822, 文心雕龍),
# (24170, 常言道),
# (54784, 大唐三藏取經詩話),
# (7340, 六韜),
# (25561, 癡人說夢記),
# (24154, 癡人說夢記),
# (23910, 封神演義),
# (25559, 中國小說史略),
# (25346, 南腔北調集),
# (27166, 吶喊),
# (24042, 徬徨),
# (25271, 朝花夕拾),
# (25423, 狂人日記),
# (25297, 狂人日記),
# (25242, 野草),
# (25332, 阿正傳),
# (23854, 文子),
# (27122, 老學庵筆記),
# (23949, 茶經),
# (7406, 茶經),
# (25249, 近思錄),
# (23981, 瀛涯勝覽),
# (24144, 瀛涯勝覽),
# (52199, 漢宮秋),
# (24178, 孟子),
# (24137, 東京夢華錄),
# (57238, 白兔記),
# (27414, 好逑傳),
# (30465, 御製廣寒殿記),
# (24240, 墨子),
# (24273, 西湖佳話),
# (27184, 癡人福),
# (25259, 公墓),
# (25194, 飲水詞集),
# (26922, 春柳鶯),
# (25218, 六一詞),
# (25431, 歸田錄),
# (25606, 三國志),
# (23947, 蜀碧),
# (25134, 九尾狐),
# (51828, 聊齋志異),
# (26161, 醒世姻緣),
# (27088, 南部新書),
# (24233, 東度記),
# (27107, 金雲翹傳),
# (56202, 拾遺記),
# (25226, 負曝閒談),
# (62791, 滬語開路),
# (24193, 燕子箋),
# (25498, 佛說無量壽經),
# (27148, 蕉葉帕),
# (23833, 商君書),
# (7383, 商子),
# (25223, 俗話傾談),
# (25366, 慎子),
# (25192, 浮生六記),
# (52238, 枕中記),
# (27292, 夢溪筆談),
# (7312, 夢溪筆談),
# (7317, 夢溪筆談),
# (7313, 夢溪筆談),
# (7314, 夢溪筆談),
# (7315, 夢溪筆談),
# (7316, 夢溪筆談),
# (25375, 諧鐸),
# (23844, 六祖壇經),
# (26737, 幽閨記),
# (23863, 水滸傳),
# (26876, 文子),
# (25376, 三俠五義),
# (24226, 史記),
# (25167, 司馬法),
# (25716, 灵历集光),
# (25716, 灵历集光),
# (23913, 莊子的故事),
# (25273, 天工開物),
# (27104, 歸蓮夢),
# (25279, 錦香亭),
# (25253, 杜陽雜編),
# (23983, 斷鴻零雁記),
# (25173, 北夢瑣言),
# (12407, 兵法),
# (23864, 孫子兵法),
# (24038, 孫子算經),
# (24114, 東坡志林),
# (24028, 東坡樂府),
# (27123, 水調歌頭),
# (25321, 蘇洵集),
# (7349, 孫子兵法道家新註解),
# (23849, 牡丹亭),
# (26970, 彭公案),
# (30544, 五孝傳),
# (7266, 搜神後記),
# (7468, 搜神後記),
# (24142, 轟天雷),
# (23878, 人間樂),
# (24422, 定情人),
# (24224, 平山冷燕),
# (23877, 玉嬌梨),
# (27105, 玉支机),
# (25636, 玉雙魚),
# (26738, 畫圖緣),
# (25399, 石點頭),
# (24079, 商界現形記),
# (25250, 合錦回文傳),
# (25137, 玉蟾記),
# (24183, 宋史),
# (12408, 周髀算經),
# (26904, 天豹圖),
# (52275, 孔雀東南飛),
# (24232, 孝經),
# (26876, 文子),
# (52280, 明鏡公案),
# (25329, 春秋配),
# (26886, 梁公九諫),
# (51620, 爾雅),
# (24111, 竹書紀年),
# (27858, 黄帝宅經),
# (54784, 大唐三藏取經詩話),
# (7221, 文淵閣四庫全書),
# (26888, 本草備要),
# (25397, 論衡),
# (25161, 魏鄭公諫錄),
# (24112, 人間詞話),
# (54784, 大唐三藏取經詩話),
# (29032, 海國春秋),
# (56202, 拾遺記),
# (24029, 冷眼观),
# (7220, 竹齋集),
# (23906, 西廂記),
# (27026, 豔異編),
# (26746, 分甘余話),
# (25214, 劍俠傳),
# (25162, 池北偶談),
# (27291, 文中子中說),
# (25314, 荀子集解),
# (27108, 醒夢駢言),
# (25328, 豆棚閒話),
# (25517, 傳習錄),
# (25142, 王陽明全集),
# (67976, 故事新讀本第一冊),
# (25160, 三字經),
# (25121, 花外集),
# (25421, 圍爐夜話),
# (27291, 文中子中說),
# (30465, 御製廣寒殿記),
# (7219, 尉繚子),
# (25187, 花月痕),
# (25219, 花月痕),
# (23843, 明月台),
# (25327, 兒女英雄傳),
# (24052, 玉壺淸話),
# (23962, 西遊記),
# (25225, 古文觀止),
# (23834, 青箱雜記),
# (25225, 古文觀止),
# (25243, 海遊記),
# (27328, 駐春園小史),
# (24113, 九命奇冤),
# (25402, 九命奇冤),
# (24099, 二十年目睹之怪現狀),
# (54567, 二十年目睹之怪現狀),
# (23865, 恨海),
# (24227, 情變),
# (27768, 瞎騙奇聞),
# (23827, 胡涂世界),
# (25347, 貞觀政要),
# (25252, 貞觀政要),
# (24156, 中國十大禁書之國色天香),
# (24032, 儒林外史),
# (23838, 楊家將),
# (52280, 明鏡公案),
# (29079, 五色石),
# (25237, 快士傳),
# (25229, 飛龍全傳),
# (25195, 風月鑒),
# (56202, 拾遺記),
# (43009, 古詩十九首),
# (52200, 金瓶梅),
# (27204, 滿江紅),
# (27185, 宛如約),
# (25286, 歡喜冤家),
# (23854, 文子),
# (25251, 八段錦),
# (24733, 辛棄疾詞選),
# (28714, 唐才子傳),
# (23838, 楊家將),
# (23842, 楊家將),
# (27082, 楊家將演義),
# (25130, 夜雨秋燈錄),
# (25348, 雙鳳奇緣),
# (23876, 徐霞客遊記),
# (25324, 玉台新詠),
# (7408, 申鑒),
# (24169, 李太白集),
# (24060, 李太白集),
# (25321, 蘇洵集),
# (25521, 玉梨魂),
# (24231, 韓湘子全傳),
# (27171, 鬼谷四友志),
# (26738, 畫圖緣),
# (27294, 方言),
# (23841, 漢書),
# (25649, 巧聯珠),
# (26748, 幻中游),
# (25289, 滄浪詩話),
# (24037, 顔氏家訓),
# (7458, 顔氏家訓),
# (25365, 顔氏家訓),
# (7454, 顔氏家訓),
# (7455, 顔氏家訓),
# (7456, 顔氏家訓),
# (7457, 顔氏家訓),
# (43010, 竹葉亭雜記),
# (25260, 豐收),
# (25602, 蘭花夢奇傳),
# (27017, 尹文子),
# (25169, 關尹子),
# (25147, 黃繡球),
# (27302, 鄰女語),
# (27734, 合浦珠),
# (26877, 珍珠舶),
# (25245, 子不語),
# (25315, 續子不語),
# (52206, 隨園詩話),
# (52267, 鶯鶯傳),
# (57278, 青樓夢),
# (27636, 沉沦),
# (27204, 滿江紅),
# (27459, 耳食錄),
# (26887, 桯史),
# (25543, 蜃樓志),
# (25284, 五鳳吟),
# (24294, 警悟鐘),
# (25350, 蕩寇志),
# (54670, 裨海紀遊),
# (25128, 孽海花),
# (25381, 幽夢影),
# (7420, 幽夢影),
# (7418, 幽夢影),
# (7419, 幽夢影),
# (27165, 西湖夢尋),
# (25401, 陶庵夢憶),
# (25414, 列仙傳),
# (24327, 何典),
# (7407, 棋經),
# (27092, 括異志),
# (24021, 杜騙新書),
# (27263, 張載集),
# (24272, 傷寒論),
# (26997, 朝野僉載),
# (24295, 遊仙窟),
# (25231, 遊仙窟),
# (24316, 花間集),
# (25131, 吳越春秋),
# (25391, 甌北詩話),
# (25125, 明皇雜錄),
# (25460, 詩品),
# (7342, 詩品),
# (25263, 周禮),
# (25392, 西湖二集),
# (23912, 千字文),
# (24075, 千字文),
# (24184, 千字文),
# (27398, 雞肋編),
# (30460, 出師表),
# (27217, 牛郎織女傳),
# (7376, 中庸章句),
# (7375, 大學章句),
# (25249, 近思錄),
# (23840, 近思錄),
# (23816, 朱子治家格言),
# (24110, 歐遊雜記),
# (25228, 樂章集),
# (25323, 狐狸緣全傳),
# (27403, 清代野记),
# (27402, 風流悟),
# (23911, 國語),
# (24136, 左傳),

# %%
for id, title in listData:
    url = f'https://www.gutenberg.org/cache/epub/{id}/pg{id}.txt'
    try:
        res = req.get(url)

        if res.status_code == 200:
            content = res.text
            contCh = re.sub(r'[^\u4e00-\u9fa5\u3000-\u303F\uff00-\uffef]', '', content)

            # Save file
            file_path = os.path.join(folderPath, f'{title}.txt')
            with open(file_path, 'w', encoding='utf-8') as f:
                f.write(contCh)
        
            print(f'已存 {title}.txt')

        else:
            print(f"無法下載 {title}")
    
    except Exception as e:
        print("下載{title}時發生錯誤: {e}")
# Out:
# 已存 豆棚閒話.txt
# 已存 戲中戲.txt
# 已存 比目魚.txt
# 已存 比目魚.txt
# 已存 三字經.txt
# 已存 山水情.txt
# 已存 山海經.txt
# 已存 施公案.txt
# 已存 施公案.txt
# 已存 易經.txt
# 已存 木蘭奇女傳.txt
# 已存 海公案.txt
# 已存 燕丹子.txt
# 已存 狄公案.txt
# 已存 百家姓.txt
# 已存 禮記.txt
# 已存 綠牡丹.txt
# 已存 詩經.txt
# 已存 麟兒報.txt
# 已存 天豹圖.txt
# 已存 梁公九諫.txt
# 已存 長恨歌.txt
# 已存 李娃傳.txt
# 已存 玉樓春.txt
# 已存 漢書.txt
# 已存 引鳳蕭.txt
# 已存 今古奇觀.txt
# 已存 後西游記.txt
# 已存 飛跎全傳.txt
# 已存 佛說四十二章經.txt
# 已存 紅樓夢.txt
# 已存 洛神賦.txt
# 已存 晁氏儒言一卷.txt
# 已存 水滸後傳.txt
# 已存 幼學瓊林.txt
# 已存 治世餘聞.txt
# 已存 琵琶記.txt
# 已存 雪月梅傳.txt
# 已存 龍川詞.txt
# 已存 三國志.txt
# 已存 隋唐演義.txt
# 已存 論語.txt
# 已存 滬語開路.txt
# 已存 白圭志.txt
# 已存 孟子字義疏證.txt
# 已存 安樂集.txt
# 已存 鄧析子.txt
# 已存 醉醒石.txt
# 已存 唐鍾馗平鬼傳.txt
# 已存 春秋繁露.txt
# 已存 虬髯客傳.txt
# 已存 吳船錄.txt
# 已存 星槎勝覽.txt
# 已存 星槎勝覽.txt
# 已存 喻世明言.txt
# 已存 平妖傳.txt
# 已存 東周列國志.txt
# 已存 警世通言.txt
# 已存 醒世恆言.txt
# 已存 封氏聞見記.txt
# 已存 白圭志.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 琵琶記.txt
# 已存 抱朴子.txt
# 已存 西京雜記.txt
# 已存 幽明錄.txt
# 已存 明鏡公案.txt
# 已存 公孫龍子.txt
# 已存 竇娥冤.txt
# 已存 竇娥寃.txt
# 已存 管子.txt
# 已存 管子.txt
# 已存 管子.txt
# 已存 鬼谷子.txt
# 已存 鬼谷子.txt
# 已存 穆天子传.txt
# 已存 漢武帝別國洞冥記.txt
# 已存 日知錄.txt
# 已存 海上花列傳.txt
# 已存 韩非子.txt
# 已存 風月夢.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 唐诗三百首.txt
# 已存 長生殿.txt
# 已存 菜根譚.txt
# 已存 菜根譚前後集.txt
# 已存 天豹圖.txt
# 已存 筠州黃檗山斷際禪師傳法心要.txt
# 已存 山水小牘.txt
# 已存 高士傳.txt
# 已存 金剛般若波羅蜜經.txt
# 已存 天妃顯聖錄.txt
# 已存 三略.txt
# 已存 明夷待訪錄.txt
# 已存 鹽鐵論.txt
# 已存 一枕奇.txt
# 已存 六祖壇經.txt
# 已存 臺灣外紀.txt
# 已存 賈誼新書.txt
# 已存 金石緣.txt
# 已存 閱微草堂筆記.txt
# 已存 醒夢駢言.txt
# 已存 孔叢子.txt
# 已存 小爾雅.txt
# 已存 續世說.txt
# 已存 桃花扇.txt
# 已存 金剛般若波羅蜜經.txt
# 已存 補紅樓夢.txt
# 已存 老子.txt
# 已存 道德經.txt
# 已存 臺灣通史唐山過海的故事.txt
# 已存 李太白集.txt
# 已存 李太白集.txt
# 已存 官場現形記.txt
# 已存 官場現形記.txt
# 已存 官場現形記.txt
# 已存 文明小史.txt
# 已存 海公案.txt
# 已存 孫子算經.txt
# 已存 列子.txt
# 已存 脾胃論.txt
# 已存 李賀詩選.txt
# 已存 文心雕龍.txt
# 已存 二刻拍案惊奇.txt
# 已存 二刻拍案驚奇.txt
# 已存 初刻拍案驚奇.txt
# 已存 殺子報.txt
# 已存 天妃顯聖錄.txt
# 已存 西海紀遊草.txt
# 已存 漱玉詞.txt
# 已存 鏡花緣.txt
# 已存 鏡花緣.txt
# 已存 李義山詩集.txt
# 已存 天豹圖.txt
# 已存 梁公九諫.txt
# 已存 淮南子.txt
# 已存 天豹圖.txt
# 已存 老殘遊記.txt
# 已存 老殘遊記.txt
# 已存 老殘遊記續集.txt
# 已存 海島算經.txt
# 已存 郁離子.txt
# 已存 人物志.txt
# 已存 隋唐嘉話.txt
# 已存 大唐新語.txt
# 已存 列仙傳.txt
# 已存 列女傳.txt
# 已存 新序.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 文心雕龍.txt
# 已存 西京雜記.txt
# 已存 舊唐書.txt
# 已存 世說新語.txt
# 已存 幽明錄.txt
# 已存 樂章集.txt
# 已存 斬鬼傳.txt
# 已存 斬鬼傳.txt
# 已存 夢中緣.txt
# 已存 合錦回文傳.txt
# 已存 無聲戲.txt
# 已存 肉蒲團.txt
# 已存 閒情偶寄.txt
# 已存 闲情偶寄.txt
# 已存 弟子規.txt
# 已存 天豹圖.txt
# 已存 庚巳編.txt
# 已存 呻吟語.txt
# 已存 三國志演義.txt
# 已存 平妖傳.txt
# 已存 平妖傳.txt
# 已存 殘唐五代史演義傳.txt
# 已存 粉妝樓.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓全傳.txt
# 已存 說唐.txt
# 已存 文心雕龍.txt
# 已存 常言道.txt
# 已存 大唐三藏取經詩話.txt
# 已存 六韜.txt
# 已存 癡人說夢記.txt
# 已存 癡人說夢記.txt
# 已存 封神演義.txt
# 已存 中國小說史略.txt
# 已存 南腔北調集.txt
# 已存 吶喊.txt
# 已存 徬徨.txt
# 已存 朝花夕拾.txt
# 已存 狂人日記.txt
# 已存 狂人日記.txt
# 已存 野草.txt
# 已存 阿正傳.txt
# 已存 文子.txt
# 已存 老學庵筆記.txt
# 已存 茶經.txt
# 已存 茶經.txt
# 已存 近思錄.txt
# 已存 瀛涯勝覽.txt
# 已存 瀛涯勝覽.txt
# 已存 漢宮秋.txt
# 已存 孟子.txt
# 已存 東京夢華錄.txt
# 已存 白兔記.txt
# 已存 好逑傳.txt
# 已存 御製廣寒殿記.txt
# 已存 墨子.txt
# 已存 西湖佳話.txt
# 已存 癡人福.txt
# 已存 公墓.txt
# 已存 飲水詞集.txt
# 已存 春柳鶯.txt
# 已存 六一詞.txt
# 已存 歸田錄.txt
# 已存 三國志.txt
# 已存 蜀碧.txt
# 已存 九尾狐.txt
# 已存 聊齋志異.txt
# 已存 醒世姻緣.txt
# 已存 南部新書.txt
# 已存 東度記.txt
# 已存 金雲翹傳.txt
# 已存 拾遺記.txt
# 已存 負曝閒談.txt
# 已存 滬語開路.txt
# 已存 燕子箋.txt
# 已存 佛說無量壽經.txt
# 已存 蕉葉帕.txt
# 已存 商君書.txt
# 已存 商子.txt
# 已存 俗話傾談.txt
# 已存 慎子.txt
# 已存 浮生六記.txt
# 已存 枕中記.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 諧鐸.txt
# 已存 六祖壇經.txt
# 已存 幽閨記.txt
# 已存 水滸傳.txt
# 已存 文子.txt
# 已存 三俠五義.txt
# 已存 史記.txt
# 已存 司馬法.txt
# 已存 灵历集光.txt
# 已存 灵历集光.txt
# 已存 莊子的故事.txt
# 已存 天工開物.txt
# 已存 歸蓮夢.txt
# 已存 錦香亭.txt
# 已存 杜陽雜編.txt
# 已存 斷鴻零雁記.txt
# 已存 北夢瑣言.txt
# 已存 兵法.txt
# 已存 孫子兵法.txt
# 已存 孫子算經.txt
# 已存 東坡志林.txt
# 已存 東坡樂府.txt
# 已存 水調歌頭.txt
# 已存 蘇洵集.txt
# 已存 孫子兵法道家新註解.txt
# 已存 牡丹亭.txt
# 已存 彭公案.txt
# 已存 五孝傳.txt
# 已存 搜神後記.txt
# 已存 搜神後記.txt
# 已存 轟天雷.txt
# 已存 人間樂.txt
# 已存 定情人.txt
# 已存 平山冷燕.txt
# 已存 玉嬌梨.txt
# 已存 玉支机.txt
# 已存 玉雙魚.txt
# 已存 畫圖緣.txt
# 已存 石點頭.txt
# 已存 商界現形記.txt
# 已存 合錦回文傳.txt
# 已存 玉蟾記.txt
# 已存 宋史.txt
# 已存 周髀算經.txt
# 已存 天豹圖.txt
# 已存 孔雀東南飛.txt
# 已存 孝經.txt
# 已存 文子.txt
# 已存 明鏡公案.txt
# 已存 春秋配.txt
# 已存 梁公九諫.txt
# 已存 爾雅.txt
# 已存 竹書紀年.txt
# 已存 黄帝宅經.txt
# 已存 大唐三藏取經詩話.txt
# 已存 文淵閣四庫全書.txt
# 已存 本草備要.txt
# 已存 論衡.txt
# 已存 魏鄭公諫錄.txt
# 已存 人間詞話.txt
# 已存 大唐三藏取經詩話.txt
# 已存 海國春秋.txt
# 已存 拾遺記.txt
# 已存 冷眼观.txt
# 已存 竹齋集.txt
# 已存 西廂記.txt
# 已存 豔異編.txt
# 已存 分甘余話.txt
# 已存 劍俠傳.txt
# 已存 池北偶談.txt
# 已存 文中子中說.txt
# 已存 荀子集解.txt
# 已存 醒夢駢言.txt
# 已存 豆棚閒話.txt
# 已存 傳習錄.txt
# 已存 王陽明全集.txt
# 已存 故事新讀本第一冊.txt
# 已存 三字經.txt
# 已存 花外集.txt
# 已存 圍爐夜話.txt
# 已存 文中子中說.txt
# 已存 御製廣寒殿記.txt
# 已存 尉繚子.txt
# 已存 花月痕.txt
# 已存 花月痕.txt
# 已存 明月台.txt
# 已存 兒女英雄傳.txt
# 已存 玉壺淸話.txt
# 已存 西遊記.txt
# 已存 古文觀止.txt
# 已存 青箱雜記.txt
# 已存 古文觀止.txt
# 已存 海遊記.txt
# 已存 駐春園小史.txt
# 已存 九命奇冤.txt
# 已存 九命奇冤.txt
# 已存 二十年目睹之怪現狀.txt
# 已存 二十年目睹之怪現狀.txt
# 已存 恨海.txt
# 已存 情變.txt
# 已存 瞎騙奇聞.txt
# 已存 胡涂世界.txt
# 已存 貞觀政要.txt
# 已存 貞觀政要.txt
# 已存 中國十大禁書之國色天香.txt
# 已存 儒林外史.txt
# 已存 楊家將.txt
# 已存 明鏡公案.txt
# 已存 五色石.txt
# 已存 快士傳.txt
# 已存 飛龍全傳.txt
# 已存 風月鑒.txt
# 已存 拾遺記.txt
# 已存 古詩十九首.txt
# 已存 金瓶梅.txt
# 已存 滿江紅.txt
# 已存 宛如約.txt
# 已存 歡喜冤家.txt
# 已存 文子.txt
# 已存 八段錦.txt
# 已存 辛棄疾詞選.txt
# 已存 唐才子傳.txt
# 已存 楊家將.txt
# 已存 楊家將.txt
# 已存 楊家將演義.txt
# 已存 夜雨秋燈錄.txt
# 已存 雙鳳奇緣.txt
# 已存 徐霞客遊記.txt
# 已存 玉台新詠.txt
# 已存 申鑒.txt
# 已存 李太白集.txt
# 已存 李太白集.txt
# 已存 蘇洵集.txt
# 已存 玉梨魂.txt
# 已存 韓湘子全傳.txt
# 已存 鬼谷四友志.txt
# 已存 畫圖緣.txt
# 已存 方言.txt
# 已存 漢書.txt
# 已存 巧聯珠.txt
# 已存 幻中游.txt
# 已存 滄浪詩話.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 竹葉亭雜記.txt
# 已存 豐收.txt
# 已存 蘭花夢奇傳.txt
# 已存 尹文子.txt
# 已存 關尹子.txt
# 已存 黃繡球.txt
# 已存 鄰女語.txt
# 已存 合浦珠.txt
# 已存 珍珠舶.txt
# 已存 子不語.txt
# 已存 續子不語.txt
# 已存 隨園詩話.txt
# 已存 鶯鶯傳.txt
# 已存 青樓夢.txt
# 已存 沉沦.txt
# 已存 滿江紅.txt
# 已存 耳食錄.txt
# 已存 桯史.txt
# 已存 蜃樓志.txt
# 已存 五鳳吟.txt
# 已存 警悟鐘.txt
# 已存 蕩寇志.txt
# 已存 裨海紀遊.txt
# 已存 孽海花.txt
# 已存 幽夢影.txt
# 已存 幽夢影.txt
# 已存 幽夢影.txt
# 已存 幽夢影.txt
# 已存 西湖夢尋.txt
# 已存 陶庵夢憶.txt
# 已存 列仙傳.txt
# 已存 何典.txt
# 已存 棋經.txt
# 已存 括異志.txt
# 已存 杜騙新書.txt
# 已存 張載集.txt
# 已存 傷寒論.txt
# 已存 朝野僉載.txt
# 已存 遊仙窟.txt
# 已存 遊仙窟.txt
# 已存 花間集.txt
# 已存 吳越春秋.txt
# 已存 甌北詩話.txt
# 已存 明皇雜錄.txt
# 已存 詩品.txt
# 已存 詩品.txt
# 已存 周禮.txt
# 已存 西湖二集.txt
# 已存 千字文.txt
# 已存 千字文.txt
# 已存 千字文.txt
# 已存 雞肋編.txt
# 已存 出師表.txt
# 已存 牛郎織女傳.txt
# 已存 中庸章句.txt
# 已存 大學章句.txt
# 已存 近思錄.txt
# 已存 近思錄.txt
# 已存 朱子治家格言.txt
# 已存 歐遊雜記.txt
# 已存 樂章集.txt
# 已存 狐狸緣全傳.txt
# 已存 清代野记.txt
# 已存 風流悟.txt
# 已存 國語.txt
# 已存 左傳.txt
# 已存 豆棚閒話.txt
# 已存 戲中戲.txt
# 已存 比目魚.txt
# 已存 比目魚.txt
# 已存 三字經.txt
# 已存 山水情.txt
# 已存 山海經.txt
# 已存 施公案.txt
# 已存 施公案.txt
# 已存 易經.txt
# 已存 木蘭奇女傳.txt
# 已存 海公案.txt
# 已存 燕丹子.txt
# 已存 狄公案.txt
# 已存 百家姓.txt
# 已存 禮記.txt
# 已存 綠牡丹.txt
# 已存 詩經.txt
# 已存 麟兒報.txt
# 已存 天豹圖.txt
# 已存 梁公九諫.txt
# 已存 長恨歌.txt
# 已存 李娃傳.txt
# 已存 玉樓春.txt
# 已存 漢書.txt
# 已存 引鳳蕭.txt
# 已存 今古奇觀.txt
# 已存 後西游記.txt
# 已存 飛跎全傳.txt
# 已存 佛說四十二章經.txt
# 已存 紅樓夢.txt
# 已存 洛神賦.txt
# 已存 晁氏儒言一卷.txt
# 已存 水滸後傳.txt
# 已存 幼學瓊林.txt
# 已存 治世餘聞.txt
# 已存 琵琶記.txt
# 已存 雪月梅傳.txt
# 已存 龍川詞.txt
# 已存 三國志.txt
# 已存 隋唐演義.txt
# 已存 論語.txt
# 已存 滬語開路.txt
# 已存 白圭志.txt
# 已存 孟子字義疏證.txt
# 已存 安樂集.txt
# 已存 鄧析子.txt
# 已存 醉醒石.txt
# 已存 唐鍾馗平鬼傳.txt
# 已存 春秋繁露.txt
# 已存 虬髯客傳.txt
# 已存 吳船錄.txt
# 已存 星槎勝覽.txt
# 已存 星槎勝覽.txt
# 已存 喻世明言.txt
# 已存 平妖傳.txt
# 已存 東周列國志.txt
# 已存 警世通言.txt
# 已存 醒世恆言.txt
# 已存 封氏聞見記.txt
# 已存 白圭志.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 搜神記.txt
# 已存 琵琶記.txt
# 已存 抱朴子.txt
# 已存 西京雜記.txt
# 已存 幽明錄.txt
# 已存 明鏡公案.txt
# 已存 公孫龍子.txt
# 已存 竇娥冤.txt
# 已存 竇娥寃.txt
# 已存 管子.txt
# 已存 管子.txt
# 已存 管子.txt
# 已存 鬼谷子.txt
# 已存 鬼谷子.txt
# 已存 穆天子传.txt
# 已存 漢武帝別國洞冥記.txt
# 已存 日知錄.txt
# 已存 海上花列傳.txt
# 已存 韩非子.txt
# 已存 風月夢.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 韓詩外傳.txt
# 已存 唐诗三百首.txt
# 已存 長生殿.txt
# 已存 菜根譚.txt
# 已存 菜根譚前後集.txt
# 已存 天豹圖.txt
# 已存 筠州黃檗山斷際禪師傳法心要.txt
# 已存 山水小牘.txt
# 已存 高士傳.txt
# 已存 金剛般若波羅蜜經.txt
# 已存 天妃顯聖錄.txt
# 已存 三略.txt
# 已存 明夷待訪錄.txt
# 已存 鹽鐵論.txt
# 已存 一枕奇.txt
# 已存 六祖壇經.txt
# 已存 臺灣外紀.txt
# 已存 賈誼新書.txt
# 已存 金石緣.txt
# 已存 閱微草堂筆記.txt
# 已存 醒夢駢言.txt
# 已存 孔叢子.txt
# 已存 小爾雅.txt
# 已存 續世說.txt
# 已存 桃花扇.txt
# 已存 金剛般若波羅蜜經.txt
# 已存 補紅樓夢.txt
# 已存 老子.txt
# 已存 道德經.txt
# 已存 臺灣通史唐山過海的故事.txt
# 已存 李太白集.txt
# 已存 李太白集.txt
# 已存 官場現形記.txt
# 已存 官場現形記.txt
# 已存 官場現形記.txt
# 已存 文明小史.txt
# 已存 海公案.txt
# 已存 孫子算經.txt
# 已存 列子.txt
# 已存 脾胃論.txt
# 已存 李賀詩選.txt
# 已存 文心雕龍.txt
# 已存 二刻拍案惊奇.txt
# 已存 二刻拍案驚奇.txt
# 已存 初刻拍案驚奇.txt
# 已存 殺子報.txt
# 已存 天妃顯聖錄.txt
# 已存 西海紀遊草.txt
# 已存 漱玉詞.txt
# 已存 鏡花緣.txt
# 已存 鏡花緣.txt
# 已存 李義山詩集.txt
# 已存 天豹圖.txt
# 已存 梁公九諫.txt
# 已存 淮南子.txt
# 已存 天豹圖.txt
# 已存 老殘遊記.txt
# 已存 老殘遊記.txt
# 已存 老殘遊記續集.txt
# 已存 海島算經.txt
# 已存 郁離子.txt
# 已存 人物志.txt
# 已存 隋唐嘉話.txt
# 已存 大唐新語.txt
# 已存 列仙傳.txt
# 已存 列女傳.txt
# 已存 新序.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 說苑.txt
# 已存 文心雕龍.txt
# 已存 西京雜記.txt
# 已存 舊唐書.txt
# 已存 世說新語.txt
# 已存 幽明錄.txt
# 已存 樂章集.txt
# 已存 斬鬼傳.txt
# 已存 斬鬼傳.txt
# 已存 夢中緣.txt
# 已存 合錦回文傳.txt
# 已存 無聲戲.txt
# 已存 肉蒲團.txt
# 已存 閒情偶寄.txt
# 已存 闲情偶寄.txt
# 已存 弟子規.txt
# 已存 天豹圖.txt
# 已存 庚巳編.txt
# 已存 呻吟語.txt
# 已存 三國志演義.txt
# 已存 平妖傳.txt
# 已存 平妖傳.txt
# 已存 殘唐五代史演義傳.txt
# 已存 粉妝樓.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓回.txt
# 已存 粉妝樓全傳.txt
# 已存 說唐.txt
# 已存 文心雕龍.txt
# 已存 常言道.txt
# 已存 大唐三藏取經詩話.txt
# 已存 六韜.txt
# 已存 癡人說夢記.txt
# 已存 癡人說夢記.txt
# 已存 封神演義.txt
# 已存 中國小說史略.txt
# 已存 南腔北調集.txt
# 已存 吶喊.txt
# 已存 徬徨.txt
# 已存 朝花夕拾.txt
# 已存 狂人日記.txt
# 已存 狂人日記.txt
# 已存 野草.txt
# 已存 阿正傳.txt
# 已存 文子.txt
# 已存 老學庵筆記.txt
# 已存 茶經.txt
# 已存 茶經.txt
# 已存 近思錄.txt
# 已存 瀛涯勝覽.txt
# 已存 瀛涯勝覽.txt
# 已存 漢宮秋.txt
# 已存 孟子.txt
# 已存 東京夢華錄.txt
# 已存 白兔記.txt
# 已存 好逑傳.txt
# 已存 御製廣寒殿記.txt
# 已存 墨子.txt
# 已存 西湖佳話.txt
# 已存 癡人福.txt
# 已存 公墓.txt
# 已存 飲水詞集.txt
# 已存 春柳鶯.txt
# 已存 六一詞.txt
# 已存 歸田錄.txt
# 已存 三國志.txt
# 已存 蜀碧.txt
# 已存 九尾狐.txt
# 已存 聊齋志異.txt
# 已存 醒世姻緣.txt
# 已存 南部新書.txt
# 已存 東度記.txt
# 已存 金雲翹傳.txt
# 已存 拾遺記.txt
# 已存 負曝閒談.txt
# 已存 滬語開路.txt
# 已存 燕子箋.txt
# 已存 佛說無量壽經.txt
# 已存 蕉葉帕.txt
# 已存 商君書.txt
# 已存 商子.txt
# 已存 俗話傾談.txt
# 已存 慎子.txt
# 已存 浮生六記.txt
# 已存 枕中記.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 夢溪筆談.txt
# 已存 諧鐸.txt
# 已存 六祖壇經.txt
# 已存 幽閨記.txt
# 已存 水滸傳.txt
# 已存 文子.txt
# 已存 三俠五義.txt
# 已存 史記.txt
# 已存 司馬法.txt
# 已存 灵历集光.txt
# 已存 灵历集光.txt
# 已存 莊子的故事.txt
# 已存 天工開物.txt
# 已存 歸蓮夢.txt
# 已存 錦香亭.txt
# 已存 杜陽雜編.txt
# 已存 斷鴻零雁記.txt
# 已存 北夢瑣言.txt
# 已存 兵法.txt
# 已存 孫子兵法.txt
# 已存 孫子算經.txt
# 已存 東坡志林.txt
# 已存 東坡樂府.txt
# 已存 水調歌頭.txt
# 已存 蘇洵集.txt
# 已存 孫子兵法道家新註解.txt
# 已存 牡丹亭.txt
# 已存 彭公案.txt
# 已存 五孝傳.txt
# 已存 搜神後記.txt
# 已存 搜神後記.txt
# 已存 轟天雷.txt
# 已存 人間樂.txt
# 已存 定情人.txt
# 已存 平山冷燕.txt
# 已存 玉嬌梨.txt
# 已存 玉支机.txt
# 已存 玉雙魚.txt
# 已存 畫圖緣.txt
# 已存 石點頭.txt
# 已存 商界現形記.txt
# 已存 合錦回文傳.txt
# 已存 玉蟾記.txt
# 已存 宋史.txt
# 已存 周髀算經.txt
# 已存 天豹圖.txt
# 已存 孔雀東南飛.txt
# 已存 孝經.txt
# 已存 文子.txt
# 已存 明鏡公案.txt
# 已存 春秋配.txt
# 已存 梁公九諫.txt
# 已存 爾雅.txt
# 已存 竹書紀年.txt
# 已存 黄帝宅經.txt
# 已存 大唐三藏取經詩話.txt
# 已存 文淵閣四庫全書.txt
# 已存 本草備要.txt
# 已存 論衡.txt
# 已存 魏鄭公諫錄.txt
# 已存 人間詞話.txt
# 已存 大唐三藏取經詩話.txt
# 已存 海國春秋.txt
# 已存 拾遺記.txt
# 已存 冷眼观.txt
# 已存 竹齋集.txt
# 已存 西廂記.txt
# 已存 豔異編.txt
# 已存 分甘余話.txt
# 已存 劍俠傳.txt
# 已存 池北偶談.txt
# 已存 文中子中說.txt
# 已存 荀子集解.txt
# 已存 醒夢駢言.txt
# 已存 豆棚閒話.txt
# 已存 傳習錄.txt
# 已存 王陽明全集.txt
# 已存 故事新讀本第一冊.txt
# 已存 三字經.txt
# 已存 花外集.txt
# 已存 圍爐夜話.txt
# 已存 文中子中說.txt
# 已存 御製廣寒殿記.txt
# 已存 尉繚子.txt
# 已存 花月痕.txt
# 已存 花月痕.txt
# 已存 明月台.txt
# 已存 兒女英雄傳.txt
# 已存 玉壺淸話.txt
# 已存 西遊記.txt
# 已存 古文觀止.txt
# 已存 青箱雜記.txt
# 已存 古文觀止.txt
# 已存 海遊記.txt
# 已存 駐春園小史.txt
# 已存 九命奇冤.txt
# 已存 九命奇冤.txt
# 已存 二十年目睹之怪現狀.txt
# 已存 二十年目睹之怪現狀.txt
# 已存 恨海.txt
# 已存 情變.txt
# 已存 瞎騙奇聞.txt
# 已存 胡涂世界.txt
# 已存 貞觀政要.txt
# 已存 貞觀政要.txt
# 已存 中國十大禁書之國色天香.txt
# 已存 儒林外史.txt
# 已存 楊家將.txt
# 已存 明鏡公案.txt
# 已存 五色石.txt
# 已存 快士傳.txt
# 已存 飛龍全傳.txt
# 已存 風月鑒.txt
# 已存 拾遺記.txt
# 已存 古詩十九首.txt
# 已存 金瓶梅.txt
# 已存 滿江紅.txt
# 已存 宛如約.txt
# 已存 歡喜冤家.txt
# 已存 文子.txt
# 已存 八段錦.txt
# 已存 辛棄疾詞選.txt
# 已存 唐才子傳.txt
# 已存 楊家將.txt
# 已存 楊家將.txt
# 已存 楊家將演義.txt
# 已存 夜雨秋燈錄.txt
# 已存 雙鳳奇緣.txt
# 已存 徐霞客遊記.txt
# 已存 玉台新詠.txt
# 已存 申鑒.txt
# 已存 李太白集.txt
# 已存 李太白集.txt
# 已存 蘇洵集.txt
# 已存 玉梨魂.txt
# 已存 韓湘子全傳.txt
# 已存 鬼谷四友志.txt
# 已存 畫圖緣.txt
# 已存 方言.txt
# 已存 漢書.txt
# 已存 巧聯珠.txt
# 已存 幻中游.txt
# 已存 滄浪詩話.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 顔氏家訓.txt
# 已存 竹葉亭雜記.txt
# 已存 豐收.txt
# 已存 蘭花夢奇傳.txt
# 已存 尹文子.txt
# 已存 關尹子.txt
# 已存 黃繡球.txt
# 已存 鄰女語.txt
# 已存 合浦珠.txt
# 已存 珍珠舶.txt
# 已存 子不語.txt
# 已存 續子不語.txt
# 已存 隨園詩話.txt
# 已存 鶯鶯傳.txt
# 已存 青樓夢.txt
# 已存 沉沦.txt
# 已存 滿江紅.txt
# 已存 耳食錄.txt
# 已存 桯史.txt
# 已存 蜃樓志.txt
# 已存 五鳳吟.txt
# 已存 警悟鐘.txt
# 已存 蕩寇志.txt
# 已存 裨海紀遊.txt
# 已存 孽海花.txt
# 已存 幽夢影.txt
# 已存 幽夢影.txt
# 已存 幽夢影.txt
# 已存 幽夢影.txt
# 已存 西湖夢尋.txt
# 已存 陶庵夢憶.txt
# 已存 列仙傳.txt
# 已存 何典.txt
# 已存 棋經.txt
# 已存 括異志.txt
# 已存 杜騙新書.txt
# 已存 張載集.txt
# 已存 傷寒論.txt
# 已存 朝野僉載.txt
# 已存 遊仙窟.txt
# 已存 遊仙窟.txt
# 已存 花間集.txt
# 已存 吳越春秋.txt
# 已存 甌北詩話.txt
# 已存 明皇雜錄.txt
# 已存 詩品.txt
# 已存 詩品.txt
# 已存 周禮.txt
# 已存 西湖二集.txt
# 已存 千字文.txt
# 已存 千字文.txt
# 已存 千字文.txt
# 已存 雞肋編.txt
# 已存 出師表.txt
# 已存 牛郎織女傳.txt
# 已存 中庸章句.txt
# 已存 大學章句.txt
# 已存 近思錄.txt
# 已存 近思錄.txt
# 已存 朱子治家格言.txt
# 已存 歐遊雜記.txt
# 已存 樂章集.txt
# 已存 狐狸緣全傳.txt
# 已存 清代野记.txt
# 已存 風流悟.txt
# 已存 國語.txt
# 已存 左傳.txt
